# %% [markdown]
# Ejercicio 50

# %%
Numero1 = input("Ingrese el primer número: ")
Numero2 = input("Ingrese el segundo número: ")
Suma = float(Numero1) + float(Numero2)
Resta = float(Numero1) - float(Numero2)
Multiplicacion = float(Numero1) * float(Numero2)
Division = float(Numero1) / float(Numero2)
print(f"La suma de {Numero1} y {Numero2} es: {Suma}")
print(f"La resta de {Numero1} y {Numero2} es: {Resta}")
print(f"La multiplicación de {Numero1} y {Numero2} es: {Multiplicacion}")
print(f"La división de {Numero1} y {Numero2} es: {Division}")
# Out:
# La suma de 10 y 4 es: 14.0
# La resta de 10 y 4 es: 6.0
# La multiplicación de 10 y 4 es: 40.0
# La división de 10 y 4 es: 2.5
