# %% [markdown]
# EXTRA1: DIVISION CUENTA CON PROPINA

# %%
nombre = input ("Ingresa el Nombre del Cliente:")
comida1 = input ("Milanesa:"), float(input ("Ingrese el precio de la Milanesa:"))
comida2 = input("Pizza:"), float(input("Ingrese el precio de la Pizza:"))
comida3 = input ("Hamburguesa:"), float(input ("Ingrese el precio de la Hamburguesa:"))
comida4 = input ("Ensalada:"), float(input ("Ingrese el precio de la Ensalada:"))
total = comida1[1] + comida2[1] + comida3[1] + comida4[1] + comida5[1]
print(f"Total de la cuenta: ${total:.2f}")

#CALCULAR PORCENTAJE DE PROPINA
comida2 = input("Pizza:"), float(input("Ingrese el precio de la Pizza:"))
propina = float(input("Ingrese el porcentaje de propina (%):"))
monto_propina = total * (propina / 100)
print(f"Propina: ${monto_propina:.2f}")
print(f"Total con propina: ${total + monto_propina:.2f}")

personas = int(input("Número de personas:"))
print(f"Pago por persona: ${ (total + monto_propina) / personas:.2f}")
# Out:
# Total de la cuenta: $1313.00
# Propina: $131.30
# Total con propina: $1444.30
# Pago por persona: $361.07

# %% [markdown]
# EXTRA 2: CONVERSOR DE MINUTOS A DIAS,HORAS Y MINUTOS

# %%
minutos = int(input("Total de minutos"))
print(f"Total de minutos: {minutos} minutos")

dias = minutos // 1440

minutos_restantes = minutos % 1440
horas = (minutos % 1440) // 60
print(f"Total de minutos: {minutos} minutos, que equivale a {dias} días y {horas} horas.")
# Out:
# Total de minutos: 100 minutos
# Total de minutos: 100 minutos, que equivale a 0 días y 1 horas.

# %% [markdown]
# Extra 3: Calificación final ponderada

# %%
Parcial = input("Parcial 1:"), float(input("Ingrese la calificación del Parcial 1:"))
Parcial2 = input("Parcial 2:"), float(input("Ingrese la calificación del Parcial 2:"))
Parcial3 = input("Parcial 3:"), float(input("Ingrese la calificación del Parcial 3:"))
Calificacion_final = (Parcial[1] + Parcial2[1] + Parcial3[1]) / 3
print(f"Tu calificación final es: {Calificacion_final:.2f}")
# Out:
# Tu calificación final es: 8.93

# %% [markdown]
# Extra 4: Conversor de moneda (MXN a USD y EUR)

# %%
USD = 18.50
EUR = 21.00

1000 / USD
1000 / EUR

Peso = float(input("Ingrese la cantidad en pesos mexicanos:"))
print(f"${Peso:.2f} MXN equivalen a:")
USD = Peso / 18.50
EUR = Peso / 21.00
print(f"USD: ${USD:.2f}")
print(f"EUR: {EUR:.2f}")
# Out:
# $1278.00 MXN equivalen a:
# USD: $69.08
# EUR: 60.86
